# %% [markdown]
# ## Download datasets

# %%
# Download the latest versions of the datasets and seve them to the 'Raw' folder

# %run download_raw_datasets.ipynb
# Out:
# importing Jupyter notebook from funcs.ipynb
# WHO-COVID19-CASES.csv file downloaded
# WHO-COVID19-VACCINES.csv file downloaded

# %% [markdown]
# ## Run ETL notebooks on the cases and vaccines datasets

# %%
# %run ETL_cases.ipynb
# Out:
# File "WHO-COVID19-CASES.parquet" has been uploaded to "processed" container.

# %%
# %run ETL_vaccines.ipynb
# Out:
# C:\Users\L_L\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (3,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# File "WHO-COVID19-VACCINES.parquet" has been uploaded to "processed" container.

# %% [markdown]
# ## Merged datasets

# %%
# Merge datasets for data analysis

# %run merge_processed_datasets.ipynb

# %% [markdown]
# ## Data Analysis

# %%
# Run the data analysis notebook and produce visualisations

# %run data_analysis.ipynb
